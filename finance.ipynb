# %%
import yfinance as yf
import pandas

# %%
vym = yf.Ticker("VYM").history(period="10y")

# %%
amzn = yf.Ticker("AMZN").history(period="10y")

# %%
ibm = yf.Ticker("IBM").history(period="10y")

# %%
gld = yf.Ticker("GLD").history(period="10y")

# %%
xle = yf.Ticker("XLE").history(period='10y')

# %%
xlp = yf.Ticker("XLP").history(period='10y')

# %%
voo = yf.Ticker("VOO").history(period='10y')

# %%
vug = yf.Ticker("VUG").history(period='10y')

# %%
fez = yf.Ticker("FEZ").history(period='10y')

# %%
vym.rename(columns={'Close':'VYM'},inplace=True)

# %%
amzn.rename(columns={'Close':'AMZN'},inplace=True)

# %%
ibm.rename(columns={'Close':'IBM'},inplace=True)

# %%
gld.rename(columns={'Close':'GLD'},inplace=True)

# %%
xle.rename(columns={"Close":"XLE"},inplace=True)

# %%
xlp.rename(columns={"Close":"XLP"},inplace=True)

# %%
voo.rename(columns={"Close":"VOO"},inplace=True)

# %%
vug.rename(columns={"Close":"VUG"},inplace=True)

# %%
fez.rename(columns={"Close":"FEZ"},inplace=True)

# %%
data = pandas.DataFrame(vym.VYM)

# %%
data = data.join(amzn.AMZN)

# %%
data = data.join(ibm.IBM)

# %%
data = data.join(gld.GLD)

# %%
data = data.join(xle.XLE)

# %%
data = data.join(xlp.XLP)

# %%
data = data.join(voo.VOO)

# %%
data = data.join(vug.VUG)

# %%
data = data.join(fez.FEZ)

# %%
# $VYM in $GLD
data['VYMG'] = data.VYM / data.GLD

# %%
# $VYM performed better than gold up until 2019
# Value Stocks lost more than Gold when Fed started tightening aggressively
data.VYMG.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# $IBM in $VYM Shares
data['IBMV'] = data.IBM / data.VYM

# %%
# $IBM stabilized and started to gain since 2022
data.IBMV.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot, matplotlib.ticker

# %%
# $AMZN vs Value
data['AMZNV'] = data.AMZN / data.VYM

# %%
# $AMZN peaked in early pandemic and has been losing ground since fiscal and monetary intervention
# $AMZN could lose 2/3 value until stabilization by Q4 2023
f = data.AMZNV.iloc[0]
data.AMZNV.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $AMZN vs Energy
data['AMZNE'] = data.AMZN / data.XLE

# %%
# Energy is now at 2018 levels and is expected to outperform the broader market until recession starts in Q3 2023
f = data.AMZNE.iloc[0]
data.AMZNE.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $AMZN vs Consumer Staples
data['AMZNP'] = data.AMZN / data.XLP

# %%
# $AMZN continues to lose against Staples, will likely stabilize ~1
f = data.AMZNP.iloc[0]
data.AMZNP.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $AMZN vs Growth
data['AMZNG'] = data.AMZN / data.VUG

# %%
f = data.AMZNG.iloc[0]
data.AMZNG.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $AMZN vs S&P 500
data['AMZNI'] = data.AMZN / data.VOO

# %%
f = data.AMZNI.iloc[0]
data.AMZNI.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $VUG vs S&P Index
data['VUGI'] = data.VUG / data.VOO

# %%
f = data.VUGI.iloc[0]
data.VUGI.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $VUG vs $VYM
data['VUGV'] = data.VUG / data.VYM

# %%
f = data.VUGV.iloc[0]
data.VUGV.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

# %%
# $VYM vs STOXX 50
data['VYMF'] = data.VYM / data.FEZ

# %%
f = data.VYMF.iloc[0]
data.VYMF.apply(lambda x: ((x / f) - 1)).plot()
pyplot.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))
